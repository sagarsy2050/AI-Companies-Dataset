# %%
#Cardinality 
df.nunique() # To determine the maximum and minimum number of variations in each column of the dataset

# %%
# Duplicates VALUE 
print(f'Duplicates in the dataset: {df.duplicated().sum()}')
print(f'Percentage of duplicates: {df.duplicated().sum()/len(df)*100}%')

# %% [markdown]
# # Examine the amounts of impurity in the columns.

# %%
#df["Minimum Project Size"].unique()
#df['Number of Employees'].nunique() 
#df['Number of Employees'].unique()# On this column, there is a lot of distrubution.
#df['Percent AI Service Focus'].nunique() 
#df['Percent AI Service Focus'].unique()# On this column, there is a lot of distrubution.
df['Average Hourly Rate'].nunique()

# %%
df["Minimum Project Size"]=df["Minimum Project Size"].str.replace('$','')# Data changes only once
df["Minimum Project Size"]=df["Minimum Project Size"].str.replace('Undisclosed','0')# Data changes only once
df["Minimum Project Size"]=df["Minimum Project Size"].str.replace('+','')# Data changes only once
df["Minimum Project Size"]=df["Minimum Project Size"].str.replace('Yerba Buena, Argentina','0')# Data changes only once
df["Minimum Project Size"]=df["Minimum Project Size"].str.replace(',','')# Data changes only once
df["Minimum Project Size"]=df["Minimum Project Size"].str.replace(' ','')# Data changes only once
df['Minimum Project Size'] = df['Minimum Project Size'].astype(int)

for i in  df['Minimum Project Size']:
    try :
            int(i)
    except:
        try :
            int(i.replace(',',''))
        except:
            print(i)
#df

# %% [markdown]
# * Average Hourly Rate *

# %%
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace('$','')# Data changes only once
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace('Undisclosed','0')# Data changes only once
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace('<','')# Data changes only once
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace('hr','')# Data changes only once
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace(',','')# Data changes only once
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace('/','')# Data changes only once
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace('+','')# Data changes only once
df["Average Hourly Rate"]=df["Average Hourly Rate"].str.replace(' ','')# Data changes only once
#df['Average Hourly Rate'] = df['Average Hourly Rate'].astype(int)

# for i in  df['Average Hourly Rate']:
#     try :
#             int(i)
#     except:
#         try :
#             int(i.replace(',',''))
#         except:
#             print(i)
# df
#df['Average Hourly Rate'].nunique()

# %% [markdown]
# * Number of Employees

# %%
df["Number of Employees"]=df["Number of Employees"].str.replace('$','')# Data changes only once
df["Number of Employees"]=df["Number of Employees"].str.replace('Freelancer','0')# Data changes only once
df["Number of Employees"]=df["Number of Employees"].str.replace('<','')# Data changes only once
df["Number of Employees"]=df["Number of Employees"].str.replace('hr','')# Data changes only once
df["Number of Employees"]=df["Number of Employees"].str.replace(',','')# Data changes only once
df["Number of Employees"]=df["Number of Employees"].str.replace('/','')# Data changes only once
df["Number of Employees"]=df["Number of Employees"].str.replace(' ','')# Data changes only once
df["Number of Employees"]=df["Number of Employees"].str.replace('+','')# Data changes only once
#df['Number of Employees'] = df['Number of Employees'].astype(int)

# for i in  df['Average Hourly Rate']:
#     try :
#             int(i)
#     except:
#         try :
#             int(i.replace(',',''))
#         except:
#             print(i)
# df
df['Number of Employees'].nunique()

# %% [markdown]
# *  Percent AI Service Focus

# %%
df["Percent AI Service Focus"]=df["Percent AI Service Focus"].str.replace('%','')# Data changes only once
df["Percent AI Service Focus"]=df["Percent AI Service Focus"].str.replace('Freelancer','0')# Data changes only once
df["Percent AI Service Focus"]=df["Percent AI Service Focus"].str.replace('50 - 249','50')

df['Percent AI Service Focus'] = df['Percent AI Service Focus'].astype(int)
df.info()

# %%
df.head(5)

# %% [markdown]
# # Percentage distribution of target data ( percent )

# %%
# Figure size 
plt.figure(figsize=(30,30))
# Pie plot
df['Percent AI Service Focus'].value_counts().plot.pie(autopct='%1.1f%%', textprops={'fontsize':12}).set_title("Target distribution")

# %%
#study the data
#dataset.hist()
sns.set_context('poster', font_scale=0.5)
df.hist(bins=25, grid=False, figsize=(15,10), color='#86bf91', zorder=2, rwidth=0.9)
plt.show()

# %%
#df['Percent AI Service Focus'].unique()# On this column, there is a lot of distrubution.
#df['Percent AI Service Focus'].nunique# On this column, there is a lot of distrubution.

# %% [markdown]
# # Density of columns

# %%
plt.figure(figsize=(10, 8))
sns.displot(df['Percent AI Service Focus'], kind="kde")

# %%
df.plot(kind='density', subplots=True, layout=(4,3), sharex=False, 
                     sharey=False,fontsize=12, figsize=(20,10))

# %% [markdown]
# # Visualization of data

# %% [markdown]
# # Finding correlation.

# %%
# heatmap graph for finding  correlation of column 
print("HEATMAP")
#get the correlation
sns.set_context('poster', font_scale=0.5)
plt.figure(figsize=(10,8))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
# Examining the variable's goal Hourly Rate Average (countplot)
plt.figure(figsize=(10,10))
sns.countplot(data=df,x = 'Average Hourly Rate',palette='plasma')

# %%
# Performing a check on the target variable Count of Employees (countplot)
plt.figure(figsize=(10,10))
sns.countplot(data=df,x = 'Number of Employees',palette='plasma')

# %%
# data visualisation on Percent column
sns.set_context('poster', font_scale=0.8)
df.groupby('Percent AI Service Focus').mean().plot(kind='bar', figsize=(20,15)) 
plt.xlabel('Percent AI Service Focus')
plt.ylabel('Minimum Project Size')
plt.title(' AI Focus Service in AI Percent')
plt.show()

# %%
import plotly 
import plotly.express as ex

# %%
ex.box(x = 'Percent AI Service Focus', y = 'Minimum Project Size',data_frame = df, template='seaborn', 
       notched=True, width=1200, height=800)
